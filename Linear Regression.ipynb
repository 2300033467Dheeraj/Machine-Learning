# %%
import numpy as np 
import matplotlib.pyplot as plt
# for labeling data in graph
import pandas as pd 
# used to import files
from sklearn.linear_model import LinearRegression
#to import formulas
from sklearn.model_selection import train_test_split

# %%
#Importing File by using pandasS 
file = pd.read_csv('Mall_customers.csv')
file.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
x = file[['Age']]  
y = file['Annual Income (k$)']
plt.scatter(x,y,color ="blue")
plt.xlabel("Age")
plt.ylabel("Annual income")
plt.title("Age and Anual income")
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
linearrig=LinearRegression()
linearrig.fit(x_train,y_train)
predictionsion = linearrig.predict(x_test)
print(predictions)
# Out:
# [61.31332161 61.408151   59.60639266 60.83917468 59.65380735 61.55039508
#  60.93400407 60.55468652 59.9857102  61.31332161 60.41244244 60.27019836
#  60.74434529 61.36073631 59.89088082 61.17107753 60.0331249  60.36502775
#  59.27448981 61.55039508 61.36073631 60.79175999 60.83917468 60.55468652
#  61.59780977 59.13224573 61.45556569 59.22707511 60.98141876 61.26590692
#  61.02883345 59.9857102  60.22278367 61.21849223 60.41244244 60.12795428
#  61.07624815 60.93400407 60.08053959 60.31761306]

# %%
plt.scatter(x_test, y_test, color='red', label="Actual Data")
plt.plot(x_test, predictions, color='green', label="Predicted Data", marker="+")
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
plt.title("Actual vs. Predicted Annual Income")
plt.show()
